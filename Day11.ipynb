# %% [markdown]
# <a href="https://colab.research.google.com/github/Raghureddy720/python-practice/blob/main/Day11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df=sns.load_dataset('taxis')
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (6433, 14)

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df['color']
# Out:
# 0       yellow
# 1       yellow
# 2       yellow
# 3       yellow
# 4       yellow
#          ...
# 6428     green
# 6429     green
# 6430     green
# 6431     green
# 6432     green
# Name: color, Length: 6433, dtype: object

# %%
df['color'].unique()
# Out:
# array(['yellow', 'green'], dtype=object)

# %%
df['color'].value_counts()
# Out:
# color
# yellow    5451
# green      982
# Name: count, dtype: int64

# %%
df['payment']
# Out:
# 0       credit card
# 1              cash
# 2       credit card
# 3       credit card
# 4       credit card
#            ...
# 6428    credit card
# 6429    credit card
# 6430           cash
# 6431    credit card
# 6432    credit card
# Name: payment, Length: 6433, dtype: object

# %%
df['payment'].unique()
# Out:
# array(['credit card', 'cash', nan], dtype=object)

# %%
df['payment'].value_counts()
# Out:
# payment
# credit card    4577
# cash           1812
# Name: count, dtype: int64

# %%
df['distance'].mean()
# Out:
# 3.024616819524328

# %%
df['distance'].median()
# Out:
# 1.64

# %%
df['distance'].min()
# Out:
# 0.0

# %%
df['distance'].max()
# Out:
# 36.7

# %%
df['distance'].quantile()
# Out:
# 1.64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
a=pd.Series(['India is my country',2,4,57,9])
a
#dtype is object
# Out:
# 0    India is my country
# 1                      2
# 2                      4
# 3                     57
# 4                      9
# dtype: object

# %%
a=pd.DataFrame([1,2,3],[2,3,4])
a
# Out:
#    0
# 2  1
# 3  2
# 4  3

# %%
a[0].max()
# Out:
# 3

# %%
df.loc[2]
# Out:
# pickup             2019-03-27 17:53:01
# dropoff            2019-03-27 18:00:25
# passengers                           1
# distance                          1.37
# fare                               7.5
# tip                               2.36
# tolls                              0.0
# total                            14.16
# color                           yellow
# payment                    credit card
# pickup_zone              Alphabet City
# dropoff_zone              West Village
# pickup_borough               Manhattan
# dropoff_borough              Manhattan
# Name: 2, dtype: object

# %%
df.iloc[2:10]
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
# 5 2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5  2.16
# 6 2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0  2.00
# 7 2019-03-22 12:47:13 2019-03-22 12:58:17           0      1.40   8.5  0.00
# 8 2019-03-23 11:48:50 2019-03-23 12:06:14           1      3.63  15.0  1.00
# 9 2019-03-08 16:18:37 2019-03-08 16:26:57           1      1.52   8.0  1.00
#
#    tolls  total   color      payment                pickup_zone  \
# 2    0.0  14.16  yellow  credit card              Alphabet City
# 3    0.0  36.95  yellow  credit card                  Hudson Sq
# 4    0.0  13.40  yellow  credit card               Midtown East
# ...

# %%
df.iloc[2:10,3:10]
# Out:
#    distance  fare   tip  tolls  total   color      payment
# 2      1.37   7.5  2.36    0.0  14.16  yellow  credit card
# 3      7.70  27.0  6.15    0.0  36.95  yellow  credit card
# 4      2.16   9.0  1.10    0.0  13.40  yellow  credit card
# 5      0.49   7.5  2.16    0.0  12.96  yellow  credit card
# 6      3.65  13.0  2.00    0.0  18.80  yellow  credit card
# 7      1.40   8.5  0.00    0.0  11.80  yellow          NaN
# 8      3.63  15.0  1.00    0.0  19.30  yellow  credit card
# 9      1.52   8.0  1.00    0.0  13.30  yellow  credit card

# %%
df.loc[2:10,['distance']]
# Out:
#     distance
# 2       1.37
# 3       7.70
# 4       2.16
# 5       0.49
# 6       3.65
# 7       1.40
# 8       3.63
# 9       1.52
# 10      3.90

# %%
df.loc[2:10,['distance','payment']]
# Out:
#     distance      payment
# 2       1.37  credit card
# 3       7.70  credit card
# 4       2.16  credit card
# 5       0.49  credit card
# 6       3.65  credit card
# 7       1.40          NaN
# 8       3.63  credit card
# 9       1.52  credit card
# 10      3.90         cash

# %%
df[2:3000]
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# 5    2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5
# 6    2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0
# ...                  ...                 ...         ...       ...   ...
# 2995 2019-03-26 18:21:34 2019-03-26 18:51:47           2     14.00  39.0
# 2996 2019-03-15 13:23:45 2019-03-15 13:36:25           1      1.20   9.5
# 2997 2019-03-12 14:08:17 2019-03-12 14:17:01           5      1.35   7.5
# 2998 2019-03-02 00:11:37 2019-03-02 00:30:11           0      2.80  14.5
# 2999 2019-03-29 13:13:47 2019-03-29 13:21:43           2      0.97   7.0
#
#        tip  tolls  total   color      payment                pickup_zone  \
# ...

# %%
a=np.random.randint(10,20,30)
a
# Out:
# array([13, 17, 10, 19, 15, 11, 13, 14, 14, 18, 13, 15, 12, 18, 15, 13, 13,
#        13, 11, 14, 13, 17, 18, 18, 16, 10, 18, 13, 11, 19])

# %%
a[a>10]
# Out:
# array([13, 17, 19, 15, 11, 13, 14, 14, 18, 13, 15, 12, 18, 15, 13, 13, 13,
#        11, 14, 13, 17, 18, 18, 16, 18, 13, 11, 19])

# %%
df[df['payment']=='cash']
# Out:
#                   pickup             dropoff  passengers  distance  fare  tip  \
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.0
# 10   2019-03-16 10:02:25 2019-03-16 10:22:29           1      3.90  17.0  0.0
# 13   2019-03-19 07:55:25 2019-03-19 08:09:17           1      1.75  10.5  0.0
# 14   2019-03-27 12:13:34 2019-03-27 12:25:48           0      2.90  11.5  0.0
# 15   2019-03-16 17:53:34 2019-03-16 18:13:57           3      2.09  13.5  0.0
# ...                  ...                 ...         ...       ...   ...  ...
# 6420 2019-03-16 15:39:23 2019-03-16 15:46:18           2      1.20   7.0  0.0
# 6422 2019-03-22 20:17:35 2019-03-22 20:36:07           1      4.02  16.0  0.0
# 6424 2019-03-30 20:52:15 2019-03-30 20:59:55           1      1.70   8.0  0.0
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.0  0.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0  0.0
#
# ...

# %%
df[df['fare']>=5.0]
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.0
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df[df['fare']>=1.0]
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...
